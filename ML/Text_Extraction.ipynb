# %%
import cv2
from PIL import Image
import pytesseract
import numpy as np

# %%
# def resize_image(original_image, new_width=None, new_height=None):

#     # Calculate the proportional height or width based on the desired dimension
#     if new_width is not None and new_height is None:
#         # Calculate height to maintain aspect ratio
#         aspect_ratio = original_image.width / original_image.height
#         new_height = int(new_width / aspect_ratio)
#     elif new_width is None and new_height is not None:
#         # Calculate width to maintain aspect ratio
#         aspect_ratio = original_image.height / original_image.width
#         new_width = int(new_height / aspect_ratio)
#     elif new_width is None and new_height is None:
#         raise ValueError("Either new_width or new_height should be specified.")

#     # Resize the image
#     resized_image = original_image.resize((new_width, new_height))

#     # Save the resized image
#     return resized_image

# # Example usage
# # input_path = "path/to/input/image.jpg"
# # output_path = "path/to/output/resized_image.jpg"
# # new_width = 300  # Set the desired width (height will be calculated to maintain aspect ratio)

# # resize_image(input_path, output_path, new_width=new_width)

# %%
import matplotlib.pyplot as plt
def display(img):
    dpi = 80

    height, width  = img.shape[:2]
    
    # What size does the figure need to be in inches to fit the image?
    figsize = width / float(dpi), height / float(dpi)

    # Create a figure of the right size with one axes that takes up the full figure
    fig = plt.figure(figsize=figsize)
    ax = fig.add_axes([0, 0, 1, 1])

    # Hide spines, ticks, etc.
    ax.axis('off')

    # Display the image.
    ax.imshow(img, cmap='gray')
    plt.show()

# %%
#pre-processing
def pre_proc(img):
    def grayscale(image):
        return cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    gray_image = grayscale(img)
    thresh, im_bw = cv2.threshold(gray_image, 130, 200, cv2.THRESH_BINARY)
    return im_bw

# %%
import cv2
from matplotlib import pyplot as plt
img_path = "/home/nishchay_13/Pictures/im.png"
image_file = img_path
img = Image.open(image_file)
print(type(img))
# img = resize_image(img, 800)
img = np.array(img)
image = img.copy()
display(img)
type(img)
text = pytesseract.image_to_string(img)
print(text)
# Out:
# <class 'PIL.PngImagePlugin.PngImageFile'>
# Besle Electronics Question Bok
#
# Question Bank for Basic Electronics (17ELN15/25)
#
# Module - 1
# Semiconductor Diodes and Applications
#
# 1. Explain the operation of pn junction diode under forward and reverse bias conditions with
# the help of V-I characteristics curve. (Dec’17 - 6M, Dec’16 - 6M, Jun'16 - 6M)
#
# 2. Explain briefly the pn junction diode characteristics. Gun ‘7 - 6M)
#
# 3. Draw and explain the V-I characteristics of a $i (Silicon) diode.
# (Dec'15 - 8M, Dec'14 - 5M)
# Draw and explain the V-I characteristics of a Ge (Germanium) diode. Gun ‘15 - 5M)
# S. Define following diode parameters: (i) Static resistance (li) Dynamic resistance
# Gif) Knee voltage (iv) Forward voltage drop (v) Maximum forward current (vi) Reverse
# saturation current (vii) Reverse breakdown voltage (vill) Peak inverse voltage (PIV)
# (6) Maximum power rating (Dec’16 - SM, MQP ‘15 - 6M)
#
# ...

# %%
from pdf2image import convert_from_path
pdf_file = '/home/nishchay_13/Downloads/WhatsApp Image 2023-12-18 at 6.52.10 PM.pdf'  
# Convert PDF to a list of PIL Image objects
images = convert_from_path(pdf_file)
# images = [resize_image(image,700) for image in images]
# print(type(images[0]))
image_arr = [np.array(image) for image in images]
for num,i in enumerate(image_arr):
    img=pre_proc(i)
    display(img)
    text = pytesseract.image_to_string(img)
    print(f"Page {num+ 1}:{text}\n{'=' * 50}\n")
# Out:
# Page 1:
#
# Bor. Beectrur .: qeeston Bork
# Question Bank for Basic Electronics (17ELN15/25)
# Module - 1
#
# Semiconductor Diodes and Applications
#
# 1d
#
# Explain the operation of pn junction diode under forward and reverse bias conditions with
# the help of V Lcharacter istics curve (Deel? OM. Dec'16 6M, fun 16 6M)
#
# bxplain briefty the pn juaction dhode char actenstics (fun‘t7 6M)
#
# Diaw and explain the Vi characteristics ofa Si (Sditon) died «
# (Dec 15 - 8M, Dec 14 - SM)
#
# Draw and explainthe V lcharactenstirs of a Ge (Gerinanium) diode (fant SM)
#
# Define following diode paramesers (1) Static resstance (st) Ovnamic resistance
# (iit) Knee voltage (iv) Forward voltage drop (+) Maumum forward current (vi) Reverse
# saturation current (sit} Reverse breakdown voltage (viii) Peak inverse voltage (PIV)
# (iu) Maximum power rating, (Dec (16 SM MQP ‘IS 6M)
#
# Explain the different diode approximation with neat firures.
#
# ...
